# %%
pwd
# Out:
# '/Users/Chen/Developer/Repository/Clevo-Emotion-Detection-Service/serverless/dev/CNNClassifier2'

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D, Input, AveragePooling2D
from keras import backend as K
import os
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wav
# %matplotlib inline


# from python_speech_features import mfcc
# from python_speech_features import delta
# from python_speech_features import logfbank

from preprocessing import readFileAndAggregateUtterance, getFeature
from keras.utils.np_utils import to_categorical
import python_speech_features
import datetime

# Build model
batch_size = 128
num_classes = 4
epochs = 100
kernalSize = 32

# %%
def calculate_XY(wavDirBase, categories):
    counter = 0
    #waveArr = list(os.walk(wavDirBase))
    waveArr0 = [os.listdir(os.path.join(wavDirBase, x)) for x in os.listdir(wavDirBase) if not os.path.isfile(x)]
    fileCount = sum([len(list1) for list1 in waveArr0])
    # waveArr = [item for sublist in waveArr0 for item in sublist]

    x_all_list = []
    y_all_list = []

    print("Start processing at {}".format(datetime.datetime.utcnow()))
    for category in categories:
        waveArr = os.listdir(os.path.join(wavDirBase, category))
        print("len(waveArr)", len(waveArr))
        for wavFile in waveArr:

            wavPath = "{}/{}/{}".format(wavDirBase, category, wavFile)
            input = getFeature(wavPath)
            input_tensor = input.reshape((1,input.shape[0], input.shape[1] ,1))

            inputs = Input(shape=(input.shape[0], input.shape[1], 1))
            x = Conv2D(kernalSize, (25, 52))(inputs)
            x = AveragePooling2D((input.shape[0]-24, 1))(x)

            model = Model(inputs=inputs, outputs=x)
            result = model.predict(input_tensor)

            x_all_list.append(result[0,0,0,:])
            y_all_list.append(categories.index(category))

            counter += 1
            if (counter % 100 == 0):
                K.clear_session()
                print("{} files have been processed at {}".format(counter, datetime.datetime.utcnow()))
    #             if (counter>=200):
    #                 break;
#             break

    x_all = np.array(x_all_list)
    y_all = np.array(y_all_list)

    return x_all, y_all

# %%
wavDirBase = "/Users/Chen/Developer/Repository/Clevo-Emotion-Detection-Service/serverless/dev/CNNClassifier2/Preproc/"
categories = ["Anger", "Happiness", "Neutral", "Sadness"]

x_all, y_all = calculate_XY(wavDirBase, categories)

print(x_all.shape)
print(y_all.shape)

np.savetxt("IEMOCAP_X", x_all)
np.savetxt("IEMOCAP_Y", y_all)
# Out:
# Start processing at 2017-10-09 19:09:38.055722
# len(waveArr) 3567
# len(waveArr) 657
# len(waveArr) 1551
# len(waveArr) 1035
# (4, 32)
# (4,)

# %%
# np.savetxt("IEMOCAP_X", x_all)
# np.savetxt("IEMOCAP_Y", y_all)

# x_test = np.loadtxt("IEMOCAP_X")
# y_test = np.loadtxt("IEMOCAP_Y")

# %%
# import numpy
# # x is your dataset
# x = numpy.random.randint(x_all.shape[0], size = x_all.shape[0])
# numpy.random.shuffle(x)
# training, test = x[:int(x_all.shape[0]*0.8)], x[int(x_all.shape[0]*0.8):]
# x_train = x_all[training,:]
# y_train = y_all[training]
# x_test = x_all[test,:]
# y_test = y_all[test]

# %%
# # x_train.shape
# x_test.shape
# Out:
# (224, 32)

# %%
# print("x_train", x_train[0:3])
# print("y_train", y_train)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x_all, y_all, test_size=0.2, random_state=0)

# %%
# Out:
# (224,)

# %%
Y_train_cat = to_categorical(Y_train)
Y_test_cat = to_categorical(Y_test)

# %%
print(X_train.shape)
print(Y_train_cat.shape)
# Out:
# (5448, 32)
# (5448, 4)

# %%
# This returns a tensor
lastModel = Sequential()
lastModel.add(Dense(units=num_classes, input_dim=kernalSize))
lastModel.add(Activation('softmax'))
# lastModel.add(Dense(10, activation='softmax'))
lastModel.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# model.compile(loss='categorical_crossentropy',
#               optimizer='rmsprop',
#               metrics=['accuracy'])
# model.add(Dense(units=10))
# model.add(Activation('softmax'))

# %%
lastModel.fit(X_train, Y_train_cat, batch_size=batch_size, epochs=epochs, verbose=1, validation_split=0.2)
# Out:
# Train on 4358 samples, validate on 1090 samples
# Epoch 1/200
# 4358/4358 [==============================] - 0s - loss: 2.3047 - acc: 0.2561 - val_loss: 2.2369 - val_acc: 0.2578
# Epoch 2/200
# 4358/4358 [==============================] - 0s - loss: 2.1311 - acc: 0.2616 - val_loss: 2.0822 - val_acc: 0.2606
# Epoch 3/200
# 4358/4358 [==============================] - 0s - loss: 1.9836 - acc: 0.2666 - val_loss: 1.9383 - val_acc: 0.2596
# Epoch 4/200
# 4358/4358 [==============================] - 0s - loss: 1.8478 - acc: 0.2740 - val_loss: 1.8055 - val_acc: 0.2679
# Epoch 5/200
# 4358/4358 [==============================] - 0s - loss: 1.7217 - acc: 0.2838 - val_loss: 1.6850 - val_acc: 0.2826
# Epoch 6/200
# 4358/4358 [==============================] - 0s - loss: 1.6109 - acc: 0.3017 - val_loss: 1.5806 - val_acc: 0.2927
# Epoch 7/200
# 4358/4358 [==============================] - 0s - loss: 1.5158 - acc: 0.3212 - val_loss: 1.4909 - val_acc: 0.3064
# Epoch 8/200
# 4358/4358 [==============================] - 0s - loss: 1.4366 - acc: 0.3417 - val_loss: 1.4158 - val_acc: 0.3294
# Epoch 9/200
# 4358/4358 [==============================] - 0s - loss: 1.3729 - acc: 0.3639 - val_loss: 1.3624 - val_acc: 0.3486
# Epoch 10/200
# 4358/4358 [==============================] - 0s - loss: 1.3243 - acc: 0.3935 - val_loss: 1.3213 - val_acc: 0.3743
# Epoch 11/200
# 4358/4358 [==============================] - 0s - loss: 1.2864 - acc: 0.4234 - val_loss: 1.2905 - val_acc: 0.4165
# Epoch 12/200
# 4358/4358 [==============================] - 0s - loss: 1.2600 - acc: 0.4553 - val_loss: 1.2699 - val_acc: 0.4587
# Epoch 13/200
# 4358/4358 [==============================] - 0s - loss: 1.2412 - acc: 0.4839 - val_loss: 1.2536 - val_acc: 0.4872
# Epoch 14/200
# 4358/4358 [==============================] - 0s - loss: 1.2273 - acc: 0.5060 - val_loss: 1.2435 - val_acc: 0.5028
# Epoch 15/200
# 4358/4358 [==============================] - 0s - loss: 1.2171 - acc: 0.5172 - val_loss: 1.2361 - val_acc: 0.5110
# Epoch 16/200
# 4358/4358 [==============================] - 0s - loss: 1.2096 - acc: 0.5204 - val_loss: 1.2301 - val_acc: 0.5147
# Epoch 17/200
# 4358/4358 [==============================] - 0s - loss: 1.2042 - acc: 0.5218 - val_loss: 1.2249 - val_acc: 0.5174
# Epoch 18/200
# 4358/4358 [==============================] - 0s - loss: 1.1999 - acc: 0.5220 - val_loss: 1.2215 - val_acc: 0.5156
# Epoch 19/200
# 4358/4358 [==============================] - 0s - loss: 1.1969 - acc: 0.5223 - val_loss: 1.2191 - val_acc: 0.5156
# Epoch 20/200
# 4358/4358 [==============================] - 0s - loss: 1.1942 - acc: 0.5218 - val_loss: 1.2174 - val_acc: 0.5174
# Epoch 21/200
# 4358/4358 [==============================] - 0s - loss: 1.1918 - acc: 0.5223 - val_loss: 1.2155 - val_acc: 0.5165
# Epoch 22/200
# 4358/4358 [==============================] - 0s - loss: 1.1896 - acc: 0.5225 - val_loss: 1.2128 - val_acc: 0.5183
# Epoch 23/200
# 4358/4358 [==============================] - 0s - loss: 1.1882 - acc: 0.5227 - val_loss: 1.2123 - val_acc: 0.5183
# Epoch 24/200
# 4358/4358 [==============================] - 0s - loss: 1.1870 - acc: 0.5225 - val_loss: 1.2125 - val_acc: 0.5183
# Epoch 25/200
# 4358/4358 [==============================] - 0s - loss: 1.1862 - acc: 0.5223 - val_loss: 1.2116 - val_acc: 0.5174
# Epoch 26/200
# 4358/4358 [==============================] - 0s - loss: 1.1854 - acc: 0.5225 - val_loss: 1.2122 - val_acc: 0.5174
# Epoch 27/200
# 4358/4358 [==============================] - 0s - loss: 1.1847 - acc: 0.5225 - val_loss: 1.2138 - val_acc: 0.5174
# Epoch 28/200
# 4358/4358 [==============================] - 0s - loss: 1.1844 - acc: 0.5223 - val_loss: 1.2125 - val_acc: 0.5183
# Epoch 29/200
# 4358/4358 [==============================] - 0s - loss: 1.1841 - acc: 0.5225 - val_loss: 1.2126 - val_acc: 0.5183
# Epoch 30/200
# 4358/4358 [==============================] - 0s - loss: 1.1839 - acc: 0.5225 - val_loss: 1.2128 - val_acc: 0.5183
# Epoch 31/200
# 4358/4358 [==============================] - 0s - loss: 1.1837 - acc: 0.5225 - val_loss: 1.2116 - val_acc: 0.5183
# Epoch 32/200
# 4358/4358 [==============================] - 0s - loss: 1.1835 - acc: 0.5225 - val_loss: 1.2096 - val_acc: 0.5183
# Epoch 33/200
# 4358/4358 [==============================] - 0s - loss: 1.1837 - acc: 0.5225 - val_loss: 1.2098 - val_acc: 0.5183
# Epoch 34/200
# 4358/4358 [==============================] - 0s - loss: 1.1832 - acc: 0.5225 - val_loss: 1.2100 - val_acc: 0.5183
# Epoch 35/200
# 4358/4358 [==============================] - 0s - loss: 1.1831 - acc: 0.5227 - val_loss: 1.2096 - val_acc: 0.5183
# Epoch 36/200
# 4358/4358 [==============================] - 0s - loss: 1.1832 - acc: 0.5225 - val_loss: 1.2096 - val_acc: 0.5183
# Epoch 37/200
# 4358/4358 [==============================] - 0s - loss: 1.1831 - acc: 0.5227 - val_loss: 1.2093 - val_acc: 0.5183
# Epoch 38/200
# 4358/4358 [==============================] - 0s - loss: 1.1831 - acc: 0.5227 - val_loss: 1.2093 - val_acc: 0.5183
# Epoch 39/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2079 - val_acc: 0.5174
# Epoch 40/200
# 4358/4358 [==============================] - 0s - loss: 1.1831 - acc: 0.5227 - val_loss: 1.2083 - val_acc: 0.5174
# Epoch 41/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2081 - val_acc: 0.5174
# Epoch 42/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2087 - val_acc: 0.5183
# Epoch 43/200
# 4358/4358 [==============================] - 0s - loss: 1.1831 - acc: 0.5227 - val_loss: 1.2068 - val_acc: 0.5183
# Epoch 44/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2068 - val_acc: 0.5183
# Epoch 45/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5225 - val_loss: 1.2068 - val_acc: 0.5183
# Epoch 46/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2068 - val_acc: 0.5183
# Epoch 47/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2081 - val_acc: 0.5183
# Epoch 48/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5225 - val_loss: 1.2096 - val_acc: 0.5183
# Epoch 49/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5225 - val_loss: 1.2096 - val_acc: 0.5183
# Epoch 50/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2098 - val_acc: 0.5183
# Epoch 51/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2095 - val_acc: 0.5183
# Epoch 52/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2095 - val_acc: 0.5183
# Epoch 53/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2104 - val_acc: 0.5183
# Epoch 54/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2107 - val_acc: 0.5183
# Epoch 55/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2110 - val_acc: 0.5183
# Epoch 56/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2104 - val_acc: 0.5183
# Epoch 57/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2098 - val_acc: 0.5165
# Epoch 58/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5225 - val_loss: 1.2106 - val_acc: 0.5174
# Epoch 59/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2107 - val_acc: 0.5165
# Epoch 60/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2101 - val_acc: 0.5174
# Epoch 61/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2099 - val_acc: 0.5174
# Epoch 62/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2091 - val_acc: 0.5183
# Epoch 63/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2090 - val_acc: 0.5183
# Epoch 64/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2077 - val_acc: 0.5183
# Epoch 65/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2072 - val_acc: 0.5183
# Epoch 66/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2079 - val_acc: 0.5174
# Epoch 67/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2095 - val_acc: 0.5174
# Epoch 68/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2094 - val_acc: 0.5174
# Epoch 69/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2091 - val_acc: 0.5183
# Epoch 70/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2087 - val_acc: 0.5183
# Epoch 71/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2091 - val_acc: 0.5174
# Epoch 72/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2090 - val_acc: 0.5183
# Epoch 73/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2078 - val_acc: 0.5183
# Epoch 74/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2082 - val_acc: 0.5183
# Epoch 75/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2079 - val_acc: 0.5183
# Epoch 76/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2080 - val_acc: 0.5183
# Epoch 77/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2088 - val_acc: 0.5183
# Epoch 78/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2081 - val_acc: 0.5183
# Epoch 79/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2071 - val_acc: 0.5183
# Epoch 80/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2076 - val_acc: 0.5174
# Epoch 81/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2082 - val_acc: 0.5183
# Epoch 82/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5225 - val_loss: 1.2092 - val_acc: 0.5183
# Epoch 83/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2086 - val_acc: 0.5183
# Epoch 84/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2089 - val_acc: 0.5183
# Epoch 85/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2091 - val_acc: 0.5183
# Epoch 86/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2096 - val_acc: 0.5183
# Epoch 87/200
# 4358/4358 [==============================] - 0s - loss: 1.1826 - acc: 0.5227 - val_loss: 1.2100 - val_acc: 0.5183
# Epoch 88/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2094 - val_acc: 0.5174
# Epoch 89/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2093 - val_acc: 0.5183
# Epoch 90/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2089 - val_acc: 0.5183
# Epoch 91/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2087 - val_acc: 0.5183
# Epoch 92/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2081 - val_acc: 0.5183
# Epoch 93/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2082 - val_acc: 0.5183
# Epoch 94/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2085 - val_acc: 0.5183
# Epoch 95/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2089 - val_acc: 0.5183
# Epoch 96/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2090 - val_acc: 0.5183
# Epoch 97/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2098 - val_acc: 0.5183
# Epoch 98/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2103 - val_acc: 0.5183
# Epoch 99/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2102 - val_acc: 0.5183
# Epoch 100/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2102 - val_acc: 0.5183
# Epoch 101/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2088 - val_acc: 0.5183
# Epoch 102/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2089 - val_acc: 0.5183
# Epoch 103/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2076 - val_acc: 0.5183
# Epoch 104/200
# 4358/4358 [==============================] - 0s - loss: 1.1826 - acc: 0.5227 - val_loss: 1.2071 - val_acc: 0.5183
# Epoch 105/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2083 - val_acc: 0.5183
# Epoch 106/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2090 - val_acc: 0.5174
# Epoch 107/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2086 - val_acc: 0.5183
# Epoch 108/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5225 - val_loss: 1.2086 - val_acc: 0.5183
# Epoch 109/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2083 - val_acc: 0.5183
# Epoch 110/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2084 - val_acc: 0.5183
# Epoch 111/200
# 4358/4358 [==============================] - 0s - loss: 1.1826 - acc: 0.5227 - val_loss: 1.2086 - val_acc: 0.5183
# Epoch 112/200
# 4358/4358 [==============================] - 0s - loss: 1.1826 - acc: 0.5227 - val_loss: 1.2095 - val_acc: 0.5183
# Epoch 113/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2102 - val_acc: 0.5183
# Epoch 114/200
# 4358/4358 [==============================] - 0s - loss: 1.1831 - acc: 0.5227 - val_loss: 1.2105 - val_acc: 0.5183
# Epoch 115/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2083 - val_acc: 0.5183
# Epoch 116/200
# 4358/4358 [==============================] - 0s - loss: 1.1825 - acc: 0.5225 - val_loss: 1.2084 - val_acc: 0.5183
# Epoch 117/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2088 - val_acc: 0.5183
# Epoch 118/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2091 - val_acc: 0.5183
# Epoch 119/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2074 - val_acc: 0.5183
# Epoch 120/200
# 4358/4358 [==============================] - 0s - loss: 1.1831 - acc: 0.5225 - val_loss: 1.2086 - val_acc: 0.5183
# Epoch 121/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2092 - val_acc: 0.5183
# Epoch 122/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2100 - val_acc: 0.5183
# Epoch 123/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2096 - val_acc: 0.5183
# Epoch 124/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2095 - val_acc: 0.5183
# Epoch 125/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2094 - val_acc: 0.5183
# Epoch 126/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2083 - val_acc: 0.5183
# Epoch 127/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2073 - val_acc: 0.5183
# Epoch 128/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2079 - val_acc: 0.5183
# Epoch 129/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2083 - val_acc: 0.5183
# Epoch 130/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2077 - val_acc: 0.5183
# Epoch 131/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2087 - val_acc: 0.5183
# Epoch 132/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2085 - val_acc: 0.5183
# Epoch 133/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2082 - val_acc: 0.5183
# Epoch 134/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2099 - val_acc: 0.5183
# Epoch 135/200
# 4358/4358 [==============================] - 0s - loss: 1.1831 - acc: 0.5227 - val_loss: 1.2107 - val_acc: 0.5183
# Epoch 136/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5225 - val_loss: 1.2116 - val_acc: 0.5174
# Epoch 137/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2105 - val_acc: 0.5183
# Epoch 138/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2116 - val_acc: 0.5174
# Epoch 139/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5225 - val_loss: 1.2102 - val_acc: 0.5174
# Epoch 140/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5225 - val_loss: 1.2097 - val_acc: 0.5174
# Epoch 141/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2088 - val_acc: 0.5174
# Epoch 142/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2097 - val_acc: 0.5183
# Epoch 143/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2098 - val_acc: 0.5165
# Epoch 144/200
# 4358/4358 [==============================] - 0s - loss: 1.1831 - acc: 0.5225 - val_loss: 1.2101 - val_acc: 0.5174
# Epoch 145/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2093 - val_acc: 0.5183
# Epoch 146/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2085 - val_acc: 0.5183
# Epoch 147/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2080 - val_acc: 0.5183
# Epoch 148/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2073 - val_acc: 0.5183
# Epoch 149/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2087 - val_acc: 0.5183
# Epoch 150/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2092 - val_acc: 0.5183
# Epoch 151/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5225 - val_loss: 1.2091 - val_acc: 0.5183
# Epoch 152/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2093 - val_acc: 0.5183
# Epoch 153/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5223 - val_loss: 1.2093 - val_acc: 0.5183
# Epoch 154/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2096 - val_acc: 0.5183
# Epoch 155/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2101 - val_acc: 0.5183
# Epoch 156/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2109 - val_acc: 0.5183
# Epoch 157/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2103 - val_acc: 0.5183
# Epoch 158/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2123 - val_acc: 0.5183
# Epoch 159/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5225 - val_loss: 1.2106 - val_acc: 0.5183
# Epoch 160/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2102 - val_acc: 0.5183
# Epoch 161/200
# 4358/4358 [==============================] - 0s - loss: 1.1826 - acc: 0.5227 - val_loss: 1.2101 - val_acc: 0.5183
# Epoch 162/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5223 - val_loss: 1.2088 - val_acc: 0.5183
# Epoch 163/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2099 - val_acc: 0.5183
# Epoch 164/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5225 - val_loss: 1.2104 - val_acc: 0.5183
# Epoch 165/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5225 - val_loss: 1.2096 - val_acc: 0.5183
# Epoch 166/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2090 - val_acc: 0.5183
# Epoch 167/200
# 4358/4358 [==============================] - 0s - loss: 1.1826 - acc: 0.5227 - val_loss: 1.2083 - val_acc: 0.5183
# Epoch 168/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2089 - val_acc: 0.5183
# Epoch 169/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2089 - val_acc: 0.5183
# Epoch 170/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2074 - val_acc: 0.5183
# Epoch 171/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2082 - val_acc: 0.5174
# Epoch 172/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2096 - val_acc: 0.5174
# Epoch 173/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5225 - val_loss: 1.2079 - val_acc: 0.5183
# Epoch 174/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2076 - val_acc: 0.5183
# Epoch 175/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2069 - val_acc: 0.5183
# Epoch 176/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2074 - val_acc: 0.5183
# Epoch 177/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2084 - val_acc: 0.5183
# Epoch 178/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5225 - val_loss: 1.2084 - val_acc: 0.5183
# Epoch 179/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2084 - val_acc: 0.5183
# Epoch 180/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2084 - val_acc: 0.5183
# Epoch 181/200
# 4358/4358 [==============================] - 0s - loss: 1.1830 - acc: 0.5227 - val_loss: 1.2082 - val_acc: 0.5183
# Epoch 182/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2091 - val_acc: 0.5183
# Epoch 183/200
# 4358/4358 [==============================] - 0s - loss: 1.1831 - acc: 0.5227 - val_loss: 1.2093 - val_acc: 0.5174
# Epoch 184/200
# 4358/4358 [==============================] - 0s - loss: 1.1826 - acc: 0.5227 - val_loss: 1.2083 - val_acc: 0.5183
# Epoch 185/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2100 - val_acc: 0.5183
# Epoch 186/200
# 4358/4358 [==============================] - 0s - loss: 1.1826 - acc: 0.5227 - val_loss: 1.2093 - val_acc: 0.5183
# Epoch 187/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2090 - val_acc: 0.5183
# Epoch 188/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2079 - val_acc: 0.5183
# Epoch 189/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2085 - val_acc: 0.5183
# Epoch 190/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2087 - val_acc: 0.5183
# Epoch 191/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2094 - val_acc: 0.5183
# Epoch 192/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5227 - val_loss: 1.2095 - val_acc: 0.5183
# Epoch 193/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2087 - val_acc: 0.5183
# Epoch 194/200
# 4358/4358 [==============================] - 0s - loss: 1.1826 - acc: 0.5227 - val_loss: 1.2097 - val_acc: 0.5183
# Epoch 195/200
# 4358/4358 [==============================] - 0s - loss: 1.1827 - acc: 0.5227 - val_loss: 1.2090 - val_acc: 0.5183
# Epoch 196/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2084 - val_acc: 0.5183
# Epoch 197/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5225 - val_loss: 1.2088 - val_acc: 0.5183
# Epoch 198/200
# 4358/4358 [==============================] - 0s - loss: 1.1828 - acc: 0.5225 - val_loss: 1.2091 - val_acc: 0.5183
# Epoch 199/200
# 4358/4358 [==============================] - 0s - loss: 1.1826 - acc: 0.5225 - val_loss: 1.2084 - val_acc: 0.5183
# Epoch 200/200
# 4358/4358 [==============================] - 0s - loss: 1.1829 - acc: 0.5227 - val_loss: 1.2095 - val_acc: 0.5183

# %%
lastModel.evaluate(X_test, Y_test_cat)
# Out:
#   32/1362 [..............................] - ETA: 0s
# [1.1919942780913411, 0.53157121870836321]

# %%
getFeature("/Users/Chen/Developer/Repository/Clevo-Emotion-Detection-Service/serverless/dev/CNNClassifier2/Preproc/Anger/Ses01F_impro01_M002.wav")
# Out:
# (287, 52)
# array([[  5.11733071e+00,   5.98800769e+00,   7.77893292e+00, ...,
#          -2.88159901e-02,   8.42821803e-03,   6.96395883e-02],
#        [  6.33712011e+00,   7.20940164e+00,   7.77566057e+00, ...,
#          -2.62853636e-02,  -1.72670064e-02,  -5.72414303e-02],
#        [  6.17165078e+00,   7.18005942e+00,   7.40502920e+00, ...,
#          -1.97783151e-03,  -1.31986642e-01,  -2.27144249e-01],
#        ...,
#        [  6.36439638e+00,   7.64017045e+00,   7.26427950e+00, ...,
#          -5.02181349e-01,  -3.63221517e-01,   7.43935631e-02],
#        [  5.51066499e+00,   7.52681444e+00,   7.58245172e+00, ...,
#          -5.29187231e-01,  -3.81412090e-01,   4.85745410e-02],
#        [  4.75511896e+00,   6.84501919e+00,   7.59563139e+00, ...,
#          -3.83579788e-01,  -2.78546633e-01,   8.01068614e-02]])

# %%
wavDir = "/Users/Chen/百度云同步盘/Startup/Clevo/数据/IEMOCAP_full_release/EmotionRecognization/wav"
emoTagsDir = "/Users/Chen/百度云同步盘/Startup/Clevo/数据/IEMOCAP_full_release/EmotionRecognization/emotionTags"

for emoFile in os.listdir(emoTagsDir):
    emoFilePath = "{}/{}".format(emoTagsDir, emoFile)
    readFileAndAggregateUtterance(emoFilePath, wavDir, "Preproc")
# Out:
# Ses01F_impro01_F000.wav is put into path: Preproc/Neutral
# Ses01F_impro01_F001.wav is put into path: Preproc/Neutral
# Ses01F_impro01_F002.wav is put into path: Preproc/Neutral
# Ses01F_impro01_F003.wav is put into path: Preproc/Anger
# Ses01F_impro01_F004.wav is put into path: Preproc/Anger
# Ses01F_impro01_F005.wav is put into path: Preproc/Neutral
# Ses01F_impro01_F006.wav is put into path: Preproc/Anger
# Ses01F_impro01_F007.wav is put into path: Preproc/Anger
# Ses01F_impro01_F008.wav is put into path: Preproc/Anger
# Ses01F_impro01_F009.wav is put into path: Preproc/Anger
# Ses01F_impro01_F010.wav is put into path: Preproc/Anger
# Ses01F_impro01_F011.wav is put into path: Preproc/Anger
# Ses01F_impro01_F012.wav is put into path: Preproc/Anger
# Ses01F_impro01_F013.wav is put into path: Preproc/Anger
# Ses01F_impro01_F015.wav is put into path: Preproc/Anger
# Ses01F_impro01_M000.wav is put into path: Preproc/Anger
# Ses01F_impro01_M001.wav is put into path: Preproc/Anger
# Ses01F_impro01_M002.wav is put into path: Preproc/Anger
# Ses01F_impro01_M003.wav is put into path: Preproc/Anger
# Ses01F_impro01_M004.wav is put into path: Preproc/Anger
# Ses01F_impro01_M005.wav is put into path: Preproc/Anger
# Ses01F_impro01_M006.wav is put into path: Preproc/Anger
# Ses01F_impro01_M007.wav is put into path: Preproc/Anger
# Ses01F_impro01_M008.wav is put into path: Preproc/Anger
# Ses01F_impro01_M009.wav is put into path: Preproc/Anger
# Ses01F_impro01_M010.wav is put into path: Preproc/Anger
# Ses01F_impro01_M011.wav is put into path: Preproc/Anger
# Ses01F_impro01_M013.wav is put into path: Preproc/Anger
# Ses01F_impro02_F000.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F001.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F002.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F004.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F005.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F007.wav is put into path: Preproc/Anger
# Ses01F_impro02_F007.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F008.wav is put into path: Preproc/Anger
# Ses01F_impro02_F008.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F010.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F012.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F013.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F014.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F015.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F017.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F019.wav is put into path: Preproc/Sadness
# Ses01F_impro02_F020.wav is put into path: Preproc/Sadness
# Ses01F_impro02_M000.wav is put into path: Preproc/Sadness
# Ses01F_impro02_M001.wav is put into path: Preproc/Sadness
# Ses01F_impro02_M002.wav is put into path: Preproc/Sadness
# Ses01F_impro02_M003.wav is put into path: Preproc/Anger
# Ses01F_impro02_M004.wav is put into path: Preproc/Anger
# Ses01F_impro02_M004.wav is put into path: Preproc/Sadness
# Ses01F_impro02_M005.wav is put into path: Preproc/Sadness
# Ses01F_impro02_M006.wav is put into path: Preproc/Anger
# Ses01F_impro02_M007.wav is put into path: Preproc/Anger
# Ses01F_impro02_M009.wav is put into path: Preproc/Sadness
# Ses01F_impro02_M010.wav is put into path: Preproc/Sadness
# Ses01F_impro02_M011.wav is put into path: Preproc/Sadness
# Ses01F_impro02_M013.wav is put into path: Preproc/Sadness
# Ses01F_impro02_M014.wav is put into path: Preproc/Sadness
# Ses01F_impro02_M016.wav is put into path: Preproc/Anger
# Ses01F_impro03_F000.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F001.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F002.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F003.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F004.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F005.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F006.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F007.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F008.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F009.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F010.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F012.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F013.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F014.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F016.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F021.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F022.wav is put into path: Preproc/Neutral
# Ses01F_impro03_F024.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F025.wav is put into path: Preproc/Happiness
# Ses01F_impro03_F026.wav is put into path: Preproc/Happiness
# Ses01F_impro03_M007.wav is put into path: Preproc/Happiness
# Ses01F_impro03_M008.wav is put into path: Preproc/Neutral
# Ses01F_impro03_M009.wav is put into path: Preproc/Neutral
# Ses01F_impro03_M011.wav is put into path: Preproc/Neutral
# Ses01F_impro03_M013.wav is put into path: Preproc/Happiness
# Ses01F_impro03_M014.wav is put into path: Preproc/Happiness
# Ses01F_impro03_M015.wav is put into path: Preproc/Happiness
# Ses01F_impro03_M016.wav is put into path: Preproc/Neutral
# Ses01F_impro03_M019.wav is put into path: Preproc/Neutral
# Ses01F_impro03_M020.wav is put into path: Preproc/Neutral
# Ses01F_impro03_M021.wav is put into path: Preproc/Neutral
# Ses01F_impro03_M023.wav is put into path: Preproc/Happiness
# Ses01F_impro03_M024.wav is put into path: Preproc/Neutral
# Ses01F_impro04_F000.wav is put into path: Preproc/Neutral
# Ses01F_impro04_F001.wav is put into path: Preproc/Neutral
# Ses01F_impro04_F005.wav is put into path: Preproc/Neutral
# Ses01F_impro04_F006.wav is put into path: Preproc/Neutral
# Ses01F_impro04_F007.wav is put into path: Preproc/Anger
# Ses01F_impro04_F010.wav is put into path: Preproc/Anger
# Ses01F_impro04_F012.wav is put into path: Preproc/Anger
# Ses01F_impro04_F015.wav is put into path: Preproc/Anger
# Ses01F_impro04_F016.wav is put into path: Preproc/Anger
# Ses01F_impro04_F017.wav is put into path: Preproc/Anger
# Ses01F_impro04_F018.wav is put into path: Preproc/Anger
# Ses01F_impro04_F019.wav is put into path: Preproc/Anger
# Ses01F_impro04_F020.wav is put into path: Preproc/Anger
# Ses01F_impro04_F021.wav is put into path: Preproc/Anger
# Ses01F_impro04_F022.wav is put into path: Preproc/Anger
# Ses01F_impro04_F023.wav is put into path: Preproc/Anger
# Ses01F_impro04_F024.wav is put into path: Preproc/Anger
# Ses01F_impro04_F025.wav is put into path: Preproc/Anger
# Ses01F_impro04_F026.wav is put into path: Preproc/Anger
# Ses01F_impro04_F027.wav is put into path: Preproc/Anger
# Ses01F_impro04_F028.wav is put into path: Preproc/Anger
# Ses01F_impro04_F029.wav is put into path: Preproc/Anger
# Ses01F_impro04_F030.wav is put into path: Preproc/Anger
# Ses01F_impro04_F031.wav is put into path: Preproc/Anger
# Ses01F_impro04_F032.wav is put into path: Preproc/Anger
# Ses01F_impro04_F033.wav is put into path: Preproc/Anger
# Ses01F_impro04_M000.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M001.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M002.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M003.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M004.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M005.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M006.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M008.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M009.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M010.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M011.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M012.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M013.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M014.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M015.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M016.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M017.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M018.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M019.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M020.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M021.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M022.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M023.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M024.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M025.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M026.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M027.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M028.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M030.wav is put into path: Preproc/Anger
# Ses01F_impro04_M031.wav is put into path: Preproc/Neutral
# Ses01F_impro04_M032.wav is put into path: Preproc/Neutral
# Ses01F_impro05_F000.wav is put into path: Preproc/Anger
# Ses01F_impro05_F001.wav is put into path: Preproc/Anger
# Ses01F_impro05_F002.wav is put into path: Preproc/Anger
# Ses01F_impro05_F003.wav is put into path: Preproc/Anger
# Ses01F_impro05_F004.wav is put into path: Preproc/Anger
# Ses01F_impro05_F005.wav is put into path: Preproc/Anger
# Ses01F_impro05_F006.wav is put into path: Preproc/Anger
# Ses01F_impro05_F007.wav is put into path: Preproc/Anger
# Ses01F_impro05_F008.wav is put into path: Preproc/Anger
# Ses01F_impro05_F009.wav is put into path: Preproc/Anger
# Ses01F_impro05_F010.wav is put into path: Preproc/Anger
# Ses01F_impro05_F011.wav is put into path: Preproc/Anger
# Ses01F_impro05_F012.wav is put into path: Preproc/Anger
# Ses01F_impro05_F013.wav is put into path: Preproc/Anger
# Ses01F_impro05_F014.wav is put into path: Preproc/Anger
# Ses01F_impro05_F015.wav is put into path: Preproc/Anger
# Ses01F_impro05_F016.wav is put into path: Preproc/Anger
# Ses01F_impro05_F017.wav is put into path: Preproc/Anger
# Ses01F_impro05_F018.wav is put into path: Preproc/Anger
# Ses01F_impro05_F019.wav is put into path: Preproc/Anger
# Ses01F_impro05_F020.wav is put into path: Preproc/Anger
# Ses01F_impro05_F021.wav is put into path: Preproc/Anger
# Ses01F_impro05_F022.wav is put into path: Preproc/Anger
# Ses01F_impro05_F023.wav is put into path: Preproc/Anger
# Ses01F_impro05_F024.wav is put into path: Preproc/Anger
# Ses01F_impro05_F025.wav is put into path: Preproc/Anger
# Ses01F_impro05_F026.wav is put into path: Preproc/Anger
# Ses01F_impro05_F027.wav is put into path: Preproc/Anger
# Ses01F_impro05_F028.wav is put into path: Preproc/Anger
# Ses01F_impro05_F029.wav is put into path: Preproc/Anger
# Ses01F_impro05_F030.wav is put into path: Preproc/Anger
# Ses01F_impro05_M001.wav is put into path: Preproc/Happiness
# Ses01F_impro05_M003.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M004.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M005.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M006.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M007.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M008.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M009.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M010.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M011.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M012.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M013.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M014.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M015.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M016.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M017.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M019.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M020.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M022.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M023.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M024.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M025.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M026.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M027.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M028.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M029.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M030.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M031.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M034.wav is put into path: Preproc/Neutral
# Ses01F_impro05_M035.wav is put into path: Preproc/Neutral
# Ses01F_impro06_F002.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F003.wav is put into path: Preproc/Neutral
# Ses01F_impro06_F004.wav is put into path: Preproc/Neutral
# Ses01F_impro06_F005.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F007.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F008.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F009.wav is put into path: Preproc/Neutral
# Ses01F_impro06_F011.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F013.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F014.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F015.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F016.wav is put into path: Preproc/Neutral
# Ses01F_impro06_F018.wav is put into path: Preproc/Neutral
# Ses01F_impro06_F020.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F021.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F022.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F023.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F024.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F025.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F026.wav is put into path: Preproc/Sadness
# Ses01F_impro06_F027.wav is put into path: Preproc/Neutral
# Ses01F_impro06_F028.wav is put into path: Preproc/Sadness
# Ses01F_impro06_M000.wav is put into path: Preproc/Sadness
# Ses01F_impro06_M004.wav is put into path: Preproc/Neutral
# Ses01F_impro06_M005.wav is put into path: Preproc/Neutral
# Ses01F_impro06_M006.wav is put into path: Preproc/Neutral
# Ses01F_impro06_M008.wav is put into path: Preproc/Neutral
# Ses01F_impro06_M009.wav is put into path: Preproc/Neutral
# Ses01F_impro06_M010.wav is put into path: Preproc/Neutral
# Ses01F_impro06_M011.wav is put into path: Preproc/Neutral
# Ses01F_impro06_M012.wav is put into path: Preproc/Neutral
# Ses01F_impro06_M013.wav is put into path: Preproc/Neutral
# Ses01F_impro06_M014.wav is put into path: Preproc/Neutral
# Ses01F_impro06_M016.wav is put into path: Preproc/Neutral
# Ses01F_impro07_F001.wav is put into path: Preproc/Happiness
# Ses01F_impro07_F006.wav is put into path: Preproc/Happiness
# Ses01F_impro07_F007.wav is put into path: Preproc/Happiness
# Ses01F_impro07_F014.wav is put into path: Preproc/Happiness
# Ses01F_impro07_F015.wav is put into path: Preproc/Happiness
# Ses01F_impro07_M012.wav is put into path: Preproc/Neutral
# Ses01F_impro07_M013.wav is put into path: Preproc/Neutral
# Ses01F_impro07_M018.wav is put into path: Preproc/Neutral
# Ses01F_impro07_M019.wav is put into path: Preproc/Happiness
# Ses01F_script01_1_F000.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F005.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_F009.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F010.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F011.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F012.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F013.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F014.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F015.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_F016.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F017.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F018.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F019.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F020.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F021.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F022.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F023.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F024.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F025.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F026.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F027.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F028.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F029.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F030.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F031.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F032.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F033.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F034.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_F035.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F036.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F037.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F038.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F039.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F040.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F041.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F042.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F043.wav is put into path: Preproc/Anger
# Ses01F_script01_1_F044.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M000.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M001.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M002.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M003.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M004.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M005.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M007.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M008.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M009.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M010.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M011.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M012.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M013.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M014.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M015.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M016.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M017.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M018.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M019.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M020.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M021.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M022.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M023.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M024.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M025.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M026.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M027.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M028.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M029.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M030.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M031.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M032.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M033.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M034.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M035.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M036.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M037.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M038.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M039.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M040.wav is put into path: Preproc/Neutral
# Ses01F_script01_1_M041.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M042.wav is put into path: Preproc/Anger
# Ses01F_script01_1_M043.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F000.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F001.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F002.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F003.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F004.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F005.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F006.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F007.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F008.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F009.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F010.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F011.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F012.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F013.wav is put into path: Preproc/Anger
# Ses01F_script01_2_F014.wav is put into path: Preproc/Anger
# Ses01F_script01_2_M001.wav is put into path: Preproc/Neutral
# Ses01F_script01_2_M003.wav is put into path: Preproc/Anger
# Ses01F_script01_2_M004.wav is put into path: Preproc/Neutral
# Ses01F_script01_2_M006.wav is put into path: Preproc/Anger
# Ses01F_script01_2_M007.wav is put into path: Preproc/Anger
# Ses01F_script01_2_M008.wav is put into path: Preproc/Neutral
# Ses01F_script01_2_M009.wav is put into path: Preproc/Anger
# Ses01F_script01_2_M010.wav is put into path: Preproc/Anger
# Ses01F_script01_2_M011.wav is put into path: Preproc/Anger
# Ses01F_script01_2_M012.wav is put into path: Preproc/Anger
# Ses01F_script01_2_M013.wav is put into path: Preproc/Anger
# Ses01F_script01_2_M014.wav is put into path: Preproc/Anger
# Ses01F_script01_2_M015.wav is put into path: Preproc/Anger
# Ses01F_script01_2_M016.wav is put into path: Preproc/Anger
# Ses01F_script01_2_M017.wav is put into path: Preproc/Anger
# Ses01F_script01_3_F000.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F001.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F002.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F003.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F004.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F005.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F006.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F007.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F008.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F009.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F010.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_F011.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_F012.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_F013.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_F014.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F015.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F016.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F017.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_F018.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_F019.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_F020.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_F021.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_F022.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F028.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F029.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F030.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_F031.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_F035.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_M000.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_M001.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_M003.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_M004.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_M005.wav is put into path: Preproc/Neutral
# Ses01F_script01_3_M008.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_M009.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_M010.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_M015.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_M016.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_M017.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_M018.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_M019.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_M020.wav is put into path: Preproc/Happiness
# Ses01F_script01_3_M021.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M022.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M023.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M024.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M025.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M026.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M027.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M028.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M029.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M030.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M032.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M033.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M036.wav is put into path: Preproc/Sadness
# Ses01F_script01_3_M037.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_F000.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_F001.wav is put into path: Preproc/Anger
# Ses01F_script02_1_F004.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_F005.wav is put into path: Preproc/Anger
# Ses01F_script02_1_F006.wav is put into path: Preproc/Anger
# Ses01F_script02_1_F007.wav is put into path: Preproc/Anger
# Ses01F_script02_1_F008.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_F009.wav is put into path: Preproc/Happiness
# Ses01F_script02_1_F010.wav is put into path: Preproc/Sadness
# Ses01F_script02_1_F013.wav is put into path: Preproc/Anger
# Ses01F_script02_1_F014.wav is put into path: Preproc/Anger
# Ses01F_script02_1_F015.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_F016.wav is put into path: Preproc/Anger
# Ses01F_script02_1_F017.wav is put into path: Preproc/Anger
# Ses01F_script02_1_F019.wav is put into path: Preproc/Anger
# Ses01F_script02_1_F021.wav is put into path: Preproc/Anger
# Ses01F_script02_1_F022.wav is put into path: Preproc/Anger
# Ses01F_script02_1_F023.wav is put into path: Preproc/Anger
# Ses01F_script02_1_F024.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_F025.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M000.wav is put into path: Preproc/Happiness
# Ses01F_script02_1_M004.wav is put into path: Preproc/Happiness
# Ses01F_script02_1_M006.wav is put into path: Preproc/Anger
# Ses01F_script02_1_M007.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M008.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M009.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M010.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M011.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M012.wav is put into path: Preproc/Anger
# Ses01F_script02_1_M013.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M014.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M015.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M018.wav is put into path: Preproc/Anger
# Ses01F_script02_1_M020.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M021.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M022.wav is put into path: Preproc/Anger
# Ses01F_script02_1_M023.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M024.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M025.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M026.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M027.wav is put into path: Preproc/Anger
# Ses01F_script02_1_M029.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M031.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M032.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M033.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M034.wav is put into path: Preproc/Neutral
# Ses01F_script02_1_M036.wav is put into path: Preproc/Happiness
# Ses01F_script02_1_M037.wav is put into path: Preproc/Happiness
# Ses01F_script02_1_M042.wav is put into path: Preproc/Happiness
# Ses01F_script02_1_M043.wav is put into path: Preproc/Happiness
# Ses01F_script02_1_M044.wav is put into path: Preproc/Happiness
# Ses01F_script02_2_F000.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_F001.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_F003.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F004.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F006.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F007.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F008.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F009.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F010.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F011.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F012.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F013.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F015.wav is put into path: Preproc/Sadness
# Ses01F_script02_2_F016.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F017.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_F019.wav is put into path: Preproc/Happiness
# Ses01F_script02_2_F021.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F022.wav is put into path: Preproc/Sadness
# Ses01F_script02_2_F023.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_F025.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F026.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_F027.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F028.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F028.wav is put into path: Preproc/Sadness
# Ses01F_script02_2_F029.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F030.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F031.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F032.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F033.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F034.wav is put into path: Preproc/Sadness
# Ses01F_script02_2_F035.wav is put into path: Preproc/Sadness
# Ses01F_script02_2_F036.wav is put into path: Preproc/Sadness
# Ses01F_script02_2_F039.wav is put into path: Preproc/Anger
# Ses01F_script02_2_F040.wav is put into path: Preproc/Sadness
# Ses01F_script02_2_F041.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_F042.wav is put into path: Preproc/Happiness
# Ses01F_script02_2_F043.wav is put into path: Preproc/Happiness
# Ses01F_script02_2_F044.wav is put into path: Preproc/Happiness
# Ses01F_script02_2_F045.wav is put into path: Preproc/Happiness
# Ses01F_script02_2_F046.wav is put into path: Preproc/Sadness
# Ses01F_script02_2_F047.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M002.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M004.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M006.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M007.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M008.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M009.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M010.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M011.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M012.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M013.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M014.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M015.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M016.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M017.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M019.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M020.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M021.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M022.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M023.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M024.wav is put into path: Preproc/Happiness
# Ses01F_script02_2_M026.wav is put into path: Preproc/Happiness
# Ses01F_script02_2_M030.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M031.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M032.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M033.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M035.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M036.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M037.wav is put into path: Preproc/Sadness
# Ses01F_script02_2_M038.wav is put into path: Preproc/Sadness
# Ses01F_script02_2_M040.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M041.wav is put into path: Preproc/Anger
# Ses01F_script02_2_M042.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M043.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M044.wav is put into path: Preproc/Happiness
# Ses01F_script02_2_M046.wav is put into path: Preproc/Happiness
# Ses01F_script02_2_M047.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M048.wav is put into path: Preproc/Neutral
# Ses01F_script02_2_M049.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_F005.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_F010.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_F011.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_F020.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_F021.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_F022.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_F029.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_F030.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_M007.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_M008.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_M009.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_M010.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_M013.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_M018.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_M025.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_M026.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_M034.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_M036.wav is put into path: Preproc/Happiness
# Ses01F_script03_1_M037.wav is put into path: Preproc/Happiness
# Ses01F_script03_2_F000.wav is put into path: Preproc/Happiness
# Ses01F_script03_2_F001.wav is put into path: Preproc/Happiness
# Ses01F_script03_2_F002.wav is put into path: Preproc/Happiness
# Ses01F_script03_2_F004.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_F005.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_F007.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F008.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F009.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F010.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F011.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F012.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F013.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F014.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F015.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F016.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F017.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F018.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F019.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F020.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F021.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F022.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F023.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F024.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F025.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F026.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F027.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F028.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F029.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F030.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_F031.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_F032.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_F033.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F034.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F035.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F036.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F037.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F038.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F039.wav is put into path: Preproc/Anger
# Ses01F_script03_2_F040.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M001.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_M002.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_M004.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_M005.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M007.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M008.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M009.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M010.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_M011.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_M012.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M013.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M014.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M015.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M016.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_M018.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_M019.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_M020.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M021.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M022.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M023.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M024.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M025.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M026.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M027.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M029.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M030.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M031.wav is put into path: Preproc/Neutral
# Ses01F_script03_2_M032.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M033.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M034.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M035.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M036.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M037.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M038.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M039.wav is put into path: Preproc/Anger
# Ses01F_script03_2_M040.wav is put into path: Preproc/Anger
# Ses01M_impro01_F000.wav is put into path: Preproc/Anger
# Ses01M_impro01_F001.wav is put into path: Preproc/Anger
# Ses01M_impro01_F006.wav is put into path: Preproc/Anger
# Ses01M_impro01_F007.wav is put into path: Preproc/Anger
# Ses01M_impro01_F008.wav is put into path: Preproc/Anger
# Ses01M_impro01_F011.wav is put into path: Preproc/Anger
# Ses01M_impro01_F012.wav is put into path: Preproc/Anger
# Ses01M_impro01_F013.wav is put into path: Preproc/Anger
# Ses01M_impro01_F014.wav is put into path: Preproc/Anger
# Ses01M_impro01_F015.wav is put into path: Preproc/Anger
# Ses01M_impro01_F016.wav is put into path: Preproc/Anger
# Ses01M_impro01_F019.wav is put into path: Preproc/Anger
# Ses01M_impro01_F020.wav is put into path: Preproc/Anger
# Ses01M_impro01_F021.wav is put into path: Preproc/Anger
# Ses01M_impro01_F022.wav is put into path: Preproc/Anger
# Ses01M_impro01_F024.wav is put into path: Preproc/Neutral
# Ses01M_impro01_F029.wav is put into path: Preproc/Anger
# Ses01M_impro01_F030.wav is put into path: Preproc/Anger
# Ses01M_impro01_M000.wav is put into path: Preproc/Anger
# Ses01M_impro01_M001.wav is put into path: Preproc/Anger
# Ses01M_impro01_M002.wav is put into path: Preproc/Anger
# Ses01M_impro01_M005.wav is put into path: Preproc/Anger
# Ses01M_impro01_M006.wav is put into path: Preproc/Anger
# Ses01M_impro01_M007.wav is put into path: Preproc/Anger
# Ses01M_impro01_M008.wav is put into path: Preproc/Anger
# Ses01M_impro01_M009.wav is put into path: Preproc/Anger
# Ses01M_impro01_M010.wav is put into path: Preproc/Anger
# Ses01M_impro01_M011.wav is put into path: Preproc/Anger
# Ses01M_impro01_M012.wav is put into path: Preproc/Anger
# Ses01M_impro01_M013.wav is put into path: Preproc/Anger
# Ses01M_impro01_M015.wav is put into path: Preproc/Anger
# Ses01M_impro01_M016.wav is put into path: Preproc/Anger
# Ses01M_impro01_M017.wav is put into path: Preproc/Anger
# Ses01M_impro01_M018.wav is put into path: Preproc/Anger
# Ses01M_impro01_M019.wav is put into path: Preproc/Anger
# Ses01M_impro01_M020.wav is put into path: Preproc/Anger
# Ses01M_impro01_M021.wav is put into path: Preproc/Anger
# Ses01M_impro01_M022.wav is put into path: Preproc/Anger
# Ses01M_impro01_M023.wav is put into path: Preproc/Anger
# Ses01M_impro01_M024.wav is put into path: Preproc/Anger
# Ses01M_impro01_M025.wav is put into path: Preproc/Anger
# Ses01M_impro01_M026.wav is put into path: Preproc/Anger
# Ses01M_impro01_M027.wav is put into path: Preproc/Anger
# Ses01M_impro01_M028.wav is put into path: Preproc/Anger
# Ses01M_impro01_M029.wav is put into path: Preproc/Anger
# Ses01M_impro01_M030.wav is put into path: Preproc/Anger
# Ses01M_impro01_M031.wav is put into path: Preproc/Anger
# Ses01M_impro01_M032.wav is put into path: Preproc/Anger
# Ses01M_impro01_M033.wav is put into path: Preproc/Anger
# Ses01M_impro02_F000.wav is put into path: Preproc/Neutral
# Ses01M_impro02_F003.wav is put into path: Preproc/Anger
# Ses01M_impro02_F004.wav is put into path: Preproc/Anger
# Ses01M_impro02_F005.wav is put into path: Preproc/Anger
# Ses01M_impro02_F006.wav is put into path: Preproc/Anger
# Ses01M_impro02_F007.wav is put into path: Preproc/Anger
# Ses01M_impro02_F008.wav is put into path: Preproc/Anger
# Ses01M_impro02_F009.wav is put into path: Preproc/Sadness
# Ses01M_impro02_F010.wav is put into path: Preproc/Sadness
# Ses01M_impro02_F013.wav is put into path: Preproc/Sadness
# Ses01M_impro02_F015.wav is put into path: Preproc/Sadness
# Ses01M_impro02_F017.wav is put into path: Preproc/Sadness
# Ses01M_impro02_F019.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M001.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M002.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M003.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M007.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M008.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M009.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M010.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M011.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M012.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M013.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M014.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M015.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M016.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M017.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M018.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M019.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M020.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M021.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M022.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M023.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M024.wav is put into path: Preproc/Sadness
# Ses01M_impro02_M025.wav is put into path: Preproc/Sadness
# Ses01M_impro03_F018.wav is put into path: Preproc/Neutral
# Ses01M_impro03_M003.wav is put into path: Preproc/Neutral
# Ses01M_impro03_M014.wav is put into path: Preproc/Neutral
# Ses01M_impro03_M018.wav is put into path: Preproc/Neutral
# Ses01M_impro03_M021.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F000.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F002.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F003.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F004.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F005.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F006.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F007.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F008.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F009.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F010.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F011.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F012.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F013.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F014.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F015.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F016.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F017.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F018.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F019.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F020.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F021.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F022.wav is put into path: Preproc/Neutral
# Ses01M_impro04_F025.wav is put into path: Preproc/Neutral
# Ses01M_impro04_M000.wav is put into path: Preproc/Anger
# Ses01M_impro04_M001.wav is put into path: Preproc/Anger
# Ses01M_impro04_M002.wav is put into path: Preproc/Anger
# Ses01M_impro04_M003.wav is put into path: Preproc/Anger
# Ses01M_impro04_M004.wav is put into path: Preproc/Anger
# Ses01M_impro04_M005.wav is put into path: Preproc/Anger
# Ses01M_impro04_M006.wav is put into path: Preproc/Anger
# Ses01M_impro04_M007.wav is put into path: Preproc/Anger
# Ses01M_impro04_M008.wav is put into path: Preproc/Anger
# Ses01M_impro04_M009.wav is put into path: Preproc/Anger
# Ses01M_impro04_M010.wav is put into path: Preproc/Anger
# Ses01M_impro04_M012.wav is put into path: Preproc/Anger
# Ses01M_impro04_M013.wav is put into path: Preproc/Anger
# Ses01M_impro04_M014.wav is put into path: Preproc/Anger
# Ses01M_impro04_M015.wav is put into path: Preproc/Anger
# Ses01M_impro04_M016.wav is put into path: Preproc/Anger
# Ses01M_impro04_M017.wav is put into path: Preproc/Anger
# Ses01M_impro04_M018.wav is put into path: Preproc/Anger
# Ses01M_impro04_M019.wav is put into path: Preproc/Anger
# Ses01M_impro04_M020.wav is put into path: Preproc/Anger
# Ses01M_impro04_M021.wav is put into path: Preproc/Anger
# Ses01M_impro04_M022.wav is put into path: Preproc/Anger
# Ses01M_impro04_M023.wav is put into path: Preproc/Anger
# Ses01M_impro04_M024.wav is put into path: Preproc/Anger
# Ses01M_impro04_M025.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F000.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F001.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F002.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F003.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F004.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F005.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F006.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F007.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F009.wav is put into path: Preproc/Anger
# Ses01M_impro05_F011.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F012.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F013.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F014.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F015.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F016.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F017.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F018.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F019.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F020.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F021.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F022.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F023.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F024.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F025.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F026.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F027.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F028.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F029.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F030.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F031.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F032.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F033.wav is put into path: Preproc/Neutral
# Ses01M_impro05_F034.wav is put into path: Preproc/Neutral
# Ses01M_impro05_M000.wav is put into path: Preproc/Anger
# ...
# Ses05M_script01_1b_M017.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M018.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M019.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M020.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M021.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M022.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M025.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M026.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M027.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M028.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M029.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M030.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M031.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M032.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M033.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M034.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M035.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M036.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M037.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M038.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M039.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M040.wav is put into path: Preproc/Anger
# Ses05M_script01_1b_M041.wav is put into path: Preproc/Anger
# Ses05M_script01_2_F002.wav is put into path: Preproc/Neutral
# Ses05M_script01_2_F004.wav is put into path: Preproc/Neutral
# Ses05M_script01_2_F005.wav is put into path: Preproc/Anger
# Ses05M_script01_2_F006.wav is put into path: Preproc/Anger
# Ses05M_script01_2_F010.wav is put into path: Preproc/Anger
# Ses05M_script01_2_F011.wav is put into path: Preproc/Anger
# Ses05M_script01_2_F012.wav is put into path: Preproc/Anger
# Ses05M_script01_2_F014.wav is put into path: Preproc/Anger
# Ses05M_script01_2_F015.wav is put into path: Preproc/Anger
# Ses05M_script01_2_F017.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M000.wav is put into path: Preproc/Neutral
# Ses05M_script01_2_M001.wav is put into path: Preproc/Neutral
# Ses05M_script01_2_M002.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M003.wav is put into path: Preproc/Neutral
# Ses05M_script01_2_M004.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M005.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M006.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M007.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M008.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M009.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M010.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M011.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M012.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M013.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M014.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M015.wav is put into path: Preproc/Anger
# Ses05M_script01_2_M016.wav is put into path: Preproc/Anger
# Ses05M_script01_3_F000.wav is put into path: Preproc/Neutral
# Ses05M_script01_3_F001.wav is put into path: Preproc/Happiness
# Ses05M_script01_3_F003.wav is put into path: Preproc/Neutral
# Ses05M_script01_3_F006.wav is put into path: Preproc/Neutral
# Ses05M_script01_3_F007.wav is put into path: Preproc/Neutral
# Ses05M_script01_3_F009.wav is put into path: Preproc/Happiness
# Ses05M_script01_3_F010.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_F012.wav is put into path: Preproc/Happiness
# Ses05M_script01_3_F014.wav is put into path: Preproc/Happiness
# Ses05M_script01_3_F016.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_F019.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_F020.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_F021.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_F022.wav is put into path: Preproc/Neutral
# Ses05M_script01_3_F023.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_F024.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_F025.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_F027.wav is put into path: Preproc/Happiness
# Ses05M_script01_3_M000.wav is put into path: Preproc/Happiness
# Ses05M_script01_3_M003.wav is put into path: Preproc/Neutral
# Ses05M_script01_3_M008.wav is put into path: Preproc/Happiness
# Ses05M_script01_3_M009.wav is put into path: Preproc/Happiness
# Ses05M_script01_3_M013.wav is put into path: Preproc/Happiness
# Ses05M_script01_3_M014.wav is put into path: Preproc/Happiness
# Ses05M_script01_3_M015.wav is put into path: Preproc/Happiness
# Ses05M_script01_3_M019.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M020.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M021.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M022.wav is put into path: Preproc/Neutral
# Ses05M_script01_3_M023.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M025.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M026.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M027.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M029.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M030.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M033.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M036.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M037.wav is put into path: Preproc/Anger
# Ses05M_script01_3_M038.wav is put into path: Preproc/Anger
# Ses05M_script01_3_M039.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M040.wav is put into path: Preproc/Sadness
# Ses05M_script01_3_M042.wav is put into path: Preproc/Happiness
# Ses05M_script02_1_F000.wav is put into path: Preproc/Sadness
# Ses05M_script02_1_F001.wav is put into path: Preproc/Neutral
# Ses05M_script02_1_F002.wav is put into path: Preproc/Anger
# Ses05M_script02_1_F003.wav is put into path: Preproc/Anger
# Ses05M_script02_1_F006.wav is put into path: Preproc/Anger
# Ses05M_script02_1_F007.wav is put into path: Preproc/Anger
# Ses05M_script02_1_F008.wav is put into path: Preproc/Anger
# Ses05M_script02_1_F009.wav is put into path: Preproc/Anger
# Ses05M_script02_1_F010.wav is put into path: Preproc/Anger
# Ses05M_script02_1_F012.wav is put into path: Preproc/Anger
# Ses05M_script02_1_F013.wav is put into path: Preproc/Anger
# Ses05M_script02_1_F014.wav is put into path: Preproc/Anger
# Ses05M_script02_1_F015.wav is put into path: Preproc/Anger
# Ses05M_script02_1_F016.wav is put into path: Preproc/Sadness
# Ses05M_script02_1_F018.wav is put into path: Preproc/Anger
# Ses05M_script02_1_F019.wav is put into path: Preproc/Anger
# Ses05M_script02_1_M016.wav is put into path: Preproc/Anger
# Ses05M_script02_1_M022.wav is put into path: Preproc/Anger
# Ses05M_script02_1_M023.wav is put into path: Preproc/Anger
# Ses05M_script02_1_M024.wav is put into path: Preproc/Anger
# Ses05M_script02_1_M025.wav is put into path: Preproc/Anger
# Ses05M_script02_2_F000.wav is put into path: Preproc/Neutral
# Ses05M_script02_2_F001.wav is put into path: Preproc/Neutral
# Ses05M_script02_2_F002.wav is put into path: Preproc/Anger
# Ses05M_script02_2_F003.wav is put into path: Preproc/Anger
# Ses05M_script02_2_F004.wav is put into path: Preproc/Anger
# Ses05M_script02_2_F005.wav is put into path: Preproc/Anger
# Ses05M_script02_2_F006.wav is put into path: Preproc/Anger
# Ses05M_script02_2_F007.wav is put into path: Preproc/Anger
# Ses05M_script02_2_F008.wav is put into path: Preproc/Anger
# Ses05M_script02_2_F009.wav is put into path: Preproc/Anger
# Ses05M_script02_2_F010.wav is put into path: Preproc/Anger
# Ses05M_script02_2_F011.wav is put into path: Preproc/Anger
# Ses05M_script02_2_F012.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F013.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F014.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F015.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F016.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F017.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F018.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F019.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F022.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F023.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F026.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F027.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F028.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F029.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F030.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F031.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F032.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_F034.wav is put into path: Preproc/Happiness
# Ses05M_script02_2_F037.wav is put into path: Preproc/Happiness
# Ses05M_script02_2_F038.wav is put into path: Preproc/Happiness
# Ses05M_script02_2_M002.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M005.wav is put into path: Preproc/Neutral
# Ses05M_script02_2_M006.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M007.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M009.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M010.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M011.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M012.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M013.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M014.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M016.wav is put into path: Preproc/Neutral
# Ses05M_script02_2_M020.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M021.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M022.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M023.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M024.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M025.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M026.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M028.wav is put into path: Preproc/Anger
# Ses05M_script02_2_M029.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_M030.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_M031.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_M032.wav is put into path: Preproc/Sadness
# Ses05M_script02_2_M034.wav is put into path: Preproc/Happiness
# Ses05M_script02_2_M035.wav is put into path: Preproc/Happiness
# Ses05M_script02_2_M036.wav is put into path: Preproc/Happiness
# Ses05M_script02_2_M037.wav is put into path: Preproc/Happiness
# Ses05M_script02_2_M040.wav is put into path: Preproc/Happiness
# Ses05M_script03_1_F011.wav is put into path: Preproc/Neutral
# Ses05M_script03_1_F012.wav is put into path: Preproc/Neutral
# Ses05M_script03_1_F013.wav is put into path: Preproc/Neutral
# Ses05M_script03_1_F015.wav is put into path: Preproc/Neutral
# Ses05M_script03_1_F017.wav is put into path: Preproc/Neutral
# Ses05M_script03_1_F020.wav is put into path: Preproc/Neutral
# Ses05M_script03_1_F031.wav is put into path: Preproc/Neutral
# Ses05M_script03_1_M003.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_F001.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_F002.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_F003.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F004.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_F005.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_F006.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_F007.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F008.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F009.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_F010.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F011.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F012.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_F013.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F014.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F015.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_F016.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F017.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F018.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F019.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F020.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F021.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F022.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F023.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_F024.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F025.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F026.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_F027.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F028.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F029.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F030.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F031.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F032.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F033.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F034.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F035.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F036.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F037.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F038.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F039.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F040.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F041.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F042.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F043.wav is put into path: Preproc/Anger
# Ses05M_script03_2_F044.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M004.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M005.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M007.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M008.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M009.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M010.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_M011.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_M012.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M013.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M014.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M015.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M016.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M017.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M018.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M019.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M020.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M021.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M022.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M023.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M024.wav is put into path: Preproc/Neutral
# Ses05M_script03_2_M025.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M026.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M027.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M028.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M029.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M030.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M031.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M032.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M033.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M034.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M035.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M036.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M037.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M038.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M039.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M040.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M041.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M042.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M043.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M044.wav is put into path: Preproc/Anger
# Ses05M_script03_2_M045.wav is put into path: Preproc/Anger

# %%
(rate,sig) = wav.read("20170623170919_642_15842777828_601.wav")

print("rate", rate)

#  - Mel Frequency Cepstral Coefficients
mfcc_feat = python_speech_features.mfcc(sig,rate)
d_mfcc_feat = python_speech_features.delta(mfcc_feat, 2)
# - Filterbank Energies
fbank_feat = python_speech_features.fbank(sig,rate)[0]
# - Log Filterbank Energies
logfbank_feat = python_speech_features.logfbank(sig,rate)

# - Spectral Subband Centroids
ssc_feat = python_speech_features.ssc(sig,rate)

# mfcc_feat = mfcc(sig,rate)
# d_mfcc_feat = delta(mfcc_feat, 2)

# fbank_feat = logfbank(sig,rate)
# Out:
# rate 8000

# %%
print("mfcc_feat shape: ", mfcc_feat.shape)
print("fbank_feat shape: ", fbank_feat.shape)
print("logfbank_feat shape: ", logfbank_feat.shape)
print("ssc_feat shape: ", ssc_feat.shape)
# Out:
# mfcc_feat shape:  (17171, 13)
# fbank_feat shape:  (17171, 26)
# logfbank_feat shape:  (17171, 26)
# ssc_feat shape:  (17171, 26)

# %%
sample_start = 1231

print("mfcc_feat")
print(mfcc_feat[sample_start:sample_start+3, :])

print("fbank_feat")
print(fbank_feat[sample_start:sample_start+3, :])

print("logfbank_feat")
print(logfbank_feat[sample_start:sample_start+3, :])

print("ssc_feat")
print(ssc_feat[sample_start:sample_start+3, :])
# Out:
# mfcc_feat
# [[ 16.13379134   4.61542291 -41.76135789  -5.2807745   10.73237904
#     3.61484241 -18.79295092  -1.82976924  -1.99055823 -31.75436637
#     8.71127836  -1.95209103  -7.79984302]
#  [ 16.11312882   6.97780363 -46.12920588   0.576429     8.11739545
#    13.63711798 -10.70017864  -4.37646628  -6.66814631 -25.61086489
#     4.36502522   0.18921123  -6.92343554]
#  [ 15.86549092  -5.54006824 -45.48896869  -9.83534552 -20.15050215
#     0.43181621 -34.00344988 -20.773685   -19.43556872 -33.14515784
#    -0.83002269   4.36631977   4.50879581]]
# fbank_feat
# [[  1.92401208e+03   2.54199852e+03   1.38746486e+04   5.50024282e+04
#     5.24447181e+03   1.67469111e+04   8.55415434e+04   2.09275494e+04
#     1.15860422e+05   1.34061197e+06   7.52085282e+05   1.41970055e+05
#     4.12949652e+06   1.84099327e+06   4.18205933e+05   9.82823130e+05
#     5.53800686e+04   2.36027224e+04   4.71348723e+03   3.69242672e+04
#     9.68200494e+04   4.20049380e+03   2.82439337e+03   2.42451414e+03
#     2.28003317e+03   2.40037200e+03]
#  [  3.38924658e+03   4.69669302e+03   1.65262216e+04   4.81164030e+04
#     3.81126691e+03   1.42437461e+04   5.55040348e+04   2.67234436e+04
#     1.61166634e+05   2.60677696e+06   9.82401024e+05   4.48525643e+05
#     2.51046230e+06   1.53604694e+06   5.30168217e+05   7.61476509e+05
#     9.11771999e+04   2.85083009e+04   2.73785039e+04   3.15244876e+04
#     4.90197385e+04   4.75969643e+03   3.02166660e+03   1.02870493e+03
#     8.79736417e+02   8.21471138e+02]
#  [  4.21571289e+01   1.68119706e+02   7.26620057e+03   7.08362737e+04
#     2.78804689e+04   3.51510924e+04   3.73826237e+04   3.99922444e+04
#     1.89275615e+05   1.88104053e+06   6.78997876e+05   2.80831307e+05
#     1.46466294e+06   1.10472127e+06   5.58139518e+05   5.90309906e+05
#     7.01991071e+04   1.33995247e+05   1.00441697e+05   2.00555232e+05
#     1.96231007e+05   6.04080667e+04   2.83337100e+04   3.55937488e+03
#     2.89274561e+03   2.82250916e+03]]
# logfbank_feat
# [[  7.56216791   7.84070587   9.53781861  10.91513261   8.56492981
#     9.72596911  11.35675742   9.94882172  11.66014149  14.10863676
#    13.530605    11.86337144  15.23366605  14.42581581  12.94372925
#    13.79818445  10.92197504  10.06911734   8.4581833   10.51662426
#    11.48060937   8.34295737   7.94604889   7.79338643   7.73194527
#     7.783379  ]
#  [  8.12836293   8.45461393   9.71270359  10.78137842   8.24571694
#     9.56407322  10.924211    10.1932965   11.9901941   14.77362514
#    13.79775488  13.01372113  14.73597748  14.24472275  13.18094963
#    13.5430146   11.42056014  10.25795058  10.21751345  10.35851991
#    10.79997832   8.46793917   8.01356381   6.93605594   6.77962234
#     6.7110968 ]
#  [  3.7414038    5.12467626   8.89098882  11.16812649  10.23568168
#    10.46741098  10.52896127  10.59644082  12.15095951  14.44733566
#    13.42837328  12.54550944  14.1971357   13.91510362  13.23236424
#    13.28840294  11.15909087  11.80555961  11.51733271  12.20884496
#    12.18704785  11.00887793  10.25180754   8.17734021   7.96996137
#     7.94538154]]
# ssc_feat
# [[   50.36134682   102.12046316   184.08527391   215.3863473    255.09423988
#     404.1077197    433.0643847    542.07385485   633.76750064
#     725.71802414   775.53425026   912.42010889  1080.77137627
#    1098.18714224  1378.03541135  1425.63866632  1608.08357653
#    1708.14248961  1965.44476364  2296.16181478  2328.70444501
#    2574.80522638  2837.84669927  3102.19582333  3383.07428728
#    3678.17235464]
#  [   47.43673971   101.82479772   180.34897942   212.29661701   267.2454325
#     399.51483657   433.85930158   543.18358093   641.44014876
#     723.02584326   767.66504792   919.00506181  1079.20881962
#    1122.95924238  1327.81730869  1432.70061605  1589.74040516
#    1731.20382462  1992.61384944  2210.31380629  2331.5126586   2606.40787844
#    2792.3178469   3096.67611354  3375.38972191  3676.62431366]
#  [   47.75028545   118.95627083   191.69108665   221.66210512
#     277.91344368   374.92727763   426.01982759   538.15668131   654.6970899
#     715.59780247   782.83452686   892.26316556  1077.95205906
#    1142.47824344  1309.18184359  1437.90871402  1656.12458278
#    1757.99747638  1986.44600335  2198.14244109  2352.1109244   2590.16842484
#    2729.75148049  3095.89212348  3377.78805379  3675.76500497]]

# %%
mfcc_feat.shape
# Out:
# (17171, 13)

# %%
print(d_mfcc_feat[1:3,:])
# Out:
# [[  0.00000000e+00   0.00000000e+00   1.26217745e-30   0.00000000e+00
#    -1.00974196e-29   0.00000000e+00  -5.04870979e-30   0.00000000e+00
#    -1.00974196e-29   0.00000000e+00   1.00974196e-29   0.00000000e+00
#     1.00974196e-29]
#  [  0.00000000e+00   0.00000000e+00   1.26217745e-30   0.00000000e+00
#    -1.00974196e-29   0.00000000e+00  -5.04870979e-30   0.00000000e+00
#    -1.00974196e-29   0.00000000e+00   1.00974196e-29   0.00000000e+00
#     1.00974196e-29]]

# %%
print(fbank_feat[1:3,:])
# Out:
# [[-36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339]
#  [-36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339]]

# %%
d_mfcc_feat.head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-705229e99d5b> in <module>()
# ----> 1 d_mfcc_feat.head(3)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
# get the data
x_train, y_train, paths_train, x_test, y_test, paths_test, class_names, sr = build_datasets(preproc=True)

# # input image dimensions
img_rows, img_cols = 96, 157
# Out:
# class_names =  ['Love, Happiness', 'Sadness, Sorrow']
# total files =  46
# os.path.exists(audio_path) True
#    get_sample_dimensions: melgram.shape =  (1, 1, 96, 157)
#
#  Loading class: Love, Happiness ( 1 of  2 classes), file 1 of 24: Preproc/Love, Happiness/334490_209_091532__3.wav.npy
#
#
#  Loading class: Sadness, Sorrow ( 2 of  2 classes), file 1 of 22: Preproc/Sadness, Sorrow/334491_208_091642__3.wav.npy
#
# Shuffling order of data...

# %%
# plt.figure(figsize=(10,10))
# start = 9;
# plt.subplot(221)
# plt.imshow(x_train[start+0,:,:,0])
# plt.subplot(222)
# plt.imshow(x_train[start+1,:,:,0])
# plt.subplot(223)
# plt.imshow(x_train[start+2,:,:,0])
# plt.subplot(224)
# plt.imshow(x_train[start+3,:,:,0])

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(class_names), activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
#           validation_split = 0.2
          validation_data=(x_test, y_test)
         )
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 36 samples, validate on 10 samples
# Epoch 1/12
# 36/36 [==============================] - 3s - loss: 0.6919 - acc: 0.5278 - val_loss: 0.6914 - val_acc: 0.5000
# Epoch 2/12
# 36/36 [==============================] - 2s - loss: 0.6722 - acc: 0.6111 - val_loss: 0.6838 - val_acc: 0.6000
# Epoch 3/12
# 36/36 [==============================] - 2s - loss: 0.6476 - acc: 0.6111 - val_loss: 0.7029 - val_acc: 0.5000
# Epoch 4/12
# 36/36 [==============================] - 2s - loss: 0.6763 - acc: 0.5833 - val_loss: 0.6676 - val_acc: 0.5000
# Epoch 5/12
# 36/36 [==============================] - 2s - loss: 0.6365 - acc: 0.7500 - val_loss: 0.7203 - val_acc: 0.5000
# Epoch 6/12
# 36/36 [==============================] - 2s - loss: 0.6710 - acc: 0.5278 - val_loss: 0.6663 - val_acc: 0.6000
# Epoch 7/12
# 36/36 [==============================] - 2s - loss: 0.6095 - acc: 0.6944 - val_loss: 0.6642 - val_acc: 0.5000
# Epoch 8/12
# 36/36 [==============================] - 2s - loss: 0.5568 - acc: 0.6944 - val_loss: 0.6368 - val_acc: 0.6000
# Epoch 9/12
# 36/36 [==============================] - 2s - loss: 0.5147 - acc: 0.8889 - val_loss: 0.6601 - val_acc: 0.5000
# Epoch 10/12
# 36/36 [==============================] - 2s - loss: 0.5247 - acc: 0.6111 - val_loss: 0.8121 - val_acc: 0.5000
# Epoch 11/12
# 36/36 [==============================] - 2s - loss: 0.6885 - acc: 0.5278 - val_loss: 1.0625 - val_acc: 0.5000
# Epoch 12/12
# 36/36 [==============================] - 2s - loss: 0.7967 - acc: 0.5278 - val_loss: 0.6821 - val_acc: 0.5000
# Test loss: 0.682080924511
# Test accuracy: 0.5

# %%
# batch_size = 128
# num_classes = 10
# epochs = 12

# # input image dimensions
# img_rows, img_cols = 28, 28

# # the data, shuffled and split between train and test sets
# (x_train, y_train), (x_test, y_test) = mnist.load_data()

# if K.image_data_format() == 'channels_first':
#     x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
#     x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
#     input_shape = (1, img_rows, img_cols)
# else:
#     x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
#     x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
#     input_shape = (img_rows, img_cols, 1)

# x_train = x_train.astype('float32')
# x_test = x_test.astype('float32')
# x_train /= 255
# x_test /= 255
# print('x_train shape:', x_train.shape)
# print(x_train.shape[0], 'train samples')
# print(x_test.shape[0], 'test samples')

# # convert class vectors to binary class matrices
# y_train = keras.utils.to_categorical(y_train, num_classes)
# y_test = keras.utils.to_categorical(y_test, num_classes)

# print(y_train.shape)
# print(y_test.shape)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# (60000, 10)
# (10000, 10)

# %%
count = 10
cate = 8

for i,y_train_data in enumerate(y_train):
    if y_train_data[cate] == 1:
        count-=1
        x_train[i]
        plt.figure()
        plt.imshow(x_train[i,:,:,0])
    if count == 0:
        break
